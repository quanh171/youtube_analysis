# %%
# =====================================================
# SETUP: Imports, API key setup, YouTube API client, 
# and function to retrieve channel statistics
# =====================================================

# %%
# Python version check (requires >= 3.7)
# !python --version
# Out:
# Python 3.13.5

# %%
# Import YouTube API client and error handling
# !pip install google-api-python-client
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import isodate  # For parsing ISO 8601 durations
from itertools import islice
from datetime import timedelta

# Import pandas for data manipulation
import pandas as pd

# %%
# -----------------------------
# YouTube API credentials
# -----------------------------

# %%
api_key = 'AIza.......'   # Developer API key
channel_id = 'UCqECaJ8Gagnn7YCbPEzWH6g'               # Example channel ID (Taylor Swift)

# Build a YouTube API client object
youtube = build('youtube', "v3", developerKey=api_key)

# %%
# -----------------------------
# Function: Get channel stats
# -----------------------------

# %%
def get_channel_stats(youtube, channel_id):
    """
    Retrieves channel-level statistics and metadata using YouTube Data API.
    
    Args:
        youtube: Authorized YouTube API client
        channel_id (str): Unique channel ID
    
    Returns:
        dict: Channel metadata (name, subscriber count, view count, 
              video count, upload playlist ID)
    """
    # Request channel info: snippet (basic info), contentDetails (playlists),
    # and statistics (subs, views, etc.)
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=channel_id
    )
    response = request.execute()

    # Extract relevant fields from API response
    data = dict(
        Channel_name=response['items'][0]['snippet']['title'],
        Subscribers=response['items'][0]['statistics']['subscriberCount'],
        Views=response['items'][0]['statistics']['viewCount'],
        Total_videos=response['items'][0]['statistics']['videoCount'],
        playlist_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    )

    return data

# %%
# -----------------------------
# Retrieve channel data
# -----------------------------

# %%
channel_statistics = get_channel_stats(youtube, channel_id)

# Convert to DataFrame for easier viewing & processing
channel_data = pd.DataFrame(channel_statistics, index=[1])
channel_data
# Out:
#    Channel_name Subscribers        Views Total_videos  \
# 1  Taylor Swift    61500000  40470597913          294
#
#                 playlist_id
# 1  UUqECaJ8Gagnn7YCbPEzWH6g

# %%
# -----------------------------
# Data cleaning: Convert types
# -----------------------------

# %%
# Convert string numbers (from API) into numeric datatypes
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])

# Check column datatypes
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
# -----------------------------
# Export data to CSV
# -----------------------------
channel_data.to_csv('ts_channel_data.csv', index=False, encoding="utf-8-sig")

# %%
# =====================================================
# VIDEO DATA: Retrieve video IDs from channel playlist,
# fetch video details, clean data, and export to CSV
# =====================================================

# %%
# -----------------------------
# Function: Get all video IDs from a playlist
# -----------------------------

# %%
def get_video_id(youtube, playlist_id):
    """
    Retrieves all video IDs from a given YouTube playlist.
    
    Args:
        youtube: Authorized YouTube API client
        playlist_id (str): ID of the playlist (usually the channel's upload playlist)
    
    Returns:
        list: All video IDs in the playlist
    """
    # Initial API request for first page of playlist items
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id
    )
    response = request.execute()

    video_ids = []
    # Collect video IDs from first page
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

    # Handle pagination (if there are more than 50 results)
    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            # Request next page
            request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            response = request.execute()

            # Append video IDs from this page
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])

            # Update token for next loop
            next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
# Retrieve all video IDs from the channel's upload playlist
video_ids = get_video_id(youtube, 'UUqECaJ8Gagnn7YCbPEzWH6g')
video_ids
# Out:
# ['9BTFD_gX6qQ',
#  'zqaLqctWP28',
#  'BLFnkfAc7iY',
#  '0Xh9s_3uRO8',
#  'w_DD-7_zVtw',
#  '58zLBjzfd4M',
#  'P0haCYjysUs',
#  'PQp643val70',
#  '-ddfFsLHNQs',
#  '0GeyBM6NS5s',
#  'UAtpbCEsJlA',
#  'K-8dOw7yuPo',
#  'w04K8z_nfDI',
#  'AFzzgQ7uCw4',
#  'ZwK7hrDC5UM',
#  'g_meC49cN5k',
#  'yj1_GJiJovg',
#  'b6zPqm0lLQs',
#  'VCTze4UuC9g',
#  'Sl6en1NPTYM',
#  'PQTA-EVc5DI',
#  'HZIg5sQrPAM',
#  '0GQ_QeZxdzo',
#  'KJXP13hqf2I',
#  'ZwlBxvnH-So',
#  'F0TUVujmtxY',
#  'AtDCWnV_Vzo',
#  'BpkmUfv1I4Q',
#  '56TZ3B8Qxsk',
#  '2hBLC7E8v3A',
#  'iMMUAd66vxo',
#  'vOZFiX6hDXQ',
#  'uEssK8o3jKg',
#  'bAi80EylyXQ',
#  'iY6Qhlua8Zw',
#  '_PsBoqNwYo4',
#  'wRKXAAV6jh4',
#  'RQMz4JDbtmI',
#  'w-FkV0EM_CU',
#  'oaBJlKXBvjk',
#  'gOtOWeD9YJk',
#  'fcVUbmdQfaE',
#  'i8_w_m6HLJ0',
#  'OKWfv-x2rdU',
#  'OOYlWF6V8t8',
#  'Mxxswu7V1Us',
#  'EVbtjaWXQVg',
#  'FQyEZZPbOb0',
#  'SBGdvxi2JmU',
#  'GZ4vaTRn0HU',
#  'U2W173hRfyA',
#  'O3wlMR0y4a4',
#  'Atdzfj8LcuY',
#  'CCUr2pNJft4',
#  'HzsQHfBA3MY',
#  'q3zqJs7JUCQ',
#  '4wOsiM2T_xc',
#  '6HIA7ouBfGY',
#  '0EKbEP2L32M',
#  '0hYY86DmqPY',
#  'GhXsnvmUQrg',
#  'b7kmP1fsGg8',
#  'QBllgPHa8aQ',
#  '7yRXgL7SaV0',
#  'RlDSGLHcZy0',
#  'ilkvTXfv2TY',
#  'pQq9eP5OFhw',
#  'zz9YgUoisOA',
#  'vaRGgiGfsw4',
#  'tNxUxm3-658',
#  'yF4ulRTCn44',
#  'vtW_4j7SsZk',
#  'lUvBk4owRNU',
#  'rnwD7veCoFQ',
#  'gp1MR2WAAXY',
#  'gir8BEqAutk',
#  'mvVBuG4IOW4',
#  'qrxsceexTBw',
#  '_Usd5X5XJXM',
#  'ZGBPKYbzSXs',
#  'FsGdznlfE2U',
#  'AppsjTInqiw',
#  'M7ySK0keirY',
#  'JhICcmiIE80',
#  'C-z-IckrQK8',
#  '89aQIli8aVU',
#  '2JgvVfOfoWI',
#  '3-BcH7KowGE',
#  '0jTGzm-6cYE',
#  'xB-RZqcoIgo',
#  'GBb8vC0DeXY',
#  'KzNLM4nmRak',
#  'US0OipWyYro',
#  'KudedLV0tP0',
#  '0FZULHCZKBc',
#  'okPrv0o_7GQ',
#  'lVkKLf4DCn8',
#  'vO6JqQpJboY',
#  'maEVfpxDB8k',
#  'idWma942CUI',
#  'oxNLRqMJMZk',
#  'hMPK2vNXr-E',
#  'qc2Z-OX9wnc',
#  'osmzwWw4RYM',
#  'UlFrV5GJA_4',
#  'pRhWAXg4xek',
#  'igIfiqqVHtA',
#  'jOD86iMAEY0',
#  'V80A8qN4fR8',
#  'IYqgVYjN3Go',
#  'EH70M5OeS4o',
#  'F5TMU6916U8',
#  'N-FYySSy0rM',
#  'Fn0er7H1Dm0',
#  'PH8Uc0Z_KRY',
#  'JlZnvyBqceY',
#  '8AR1dKawCi8',
#  '4cC6fw8EqWU',
#  '6-x1AlDudZw',
#  'yJTfs8YS2w0',
#  'XzOvgu3GPwY',
#  '_f4yoKJL7IQ',
#  'Hoi-PI8QpTU',
#  '2CnUYMmEHrs',
#  'YvyeAwoZ76w',
#  'anqxTwGE_nQ',
#  'kE31ShDEOwg',
#  'nfFujEdM0_E',
#  'ZZtamrXjB_w',
#  'pCH19_8E4Hw',
#  '6DdAzVDVBpw',
#  'h8DLofLM7No',
#  'HqDZxtMIx0M',
#  'M0Ku_op-LXI',
#  'nF4Jc9sPPug',
#  'ijjGqwdXa1c',
#  'eSLO-HpSWD0',
#  'uybMJ8cSWtA',
#  'Cd3v_pRgOp8',
#  'NbS4s_6jYTg',
#  'T1d9PiRAJNM',
#  'IVQqOzFKN2M',
#  'uhjx7FemU6o',
#  'lM1P2JwZ5jE',
#  'yJ_GML26Xk4',
#  'b7QlX3yR2xs',
#  'ycE7bUq3-2k',
#  'ySZGZrcqvr4',
#  'xTXsKMXUi7w',
#  'xxrf_QBD5DE',
#  'lvHZjvIyqsk',
#  'mkR_Qwix4Ho',
#  'rn0brgg2BpI',
#  'iFX6_9h7th0',
#  'rg18Kf4en2o',
#  'l8Tps3PITx4',
#  'X0Jti9F-oQA',
#  'XzKSPRqFg9E',
#  'Y2a73EvnZ4s',
#  'Uoey4W_3bos',
#  'Tmz1lz0zcLQ',
#  'XqN2qFvY64U',
#  'B-MfwP_RmHY',
#  'Odh9ddPUkEY',
#  '7Gbg6Z70J7E',
#  '-qee6dFKlw4',
#  'U1IqinpmpQE',
#  '9Wx2It8SbLs',
#  'b1kbLwvqugk',
#  'Jo-8VaRU4ok',
#  '3fUS9GAMxv4',
#  'egxyRSb_XtI',
#  '3Q94kA7llGw',
#  'mvxQYPR4lmU',
#  'mCWRjuhRRYg',
#  'gRo0ZtgB2io',
#  'r0yq_yXFQhg',
#  'pPrdGE4w9ZM',
#  'UDzPTerKZn8',
#  '5UMCrq-bBCg',
#  'nJr_8l0AEWE',
#  'tollGa3S0o8',
#  'sRxrwjOtIag',
#  'lPvcwgEuKTg',
#  'R_rUYuFtNO4',
#  'flv8AEWrRMI',
#  'u1D1AgDfreg',
#  'zJFcr1KyFqE',
#  'w1AV_35zVwU',
#  'TqAollrUJdA',
#  'OhJ-S9Nrh7Q',
#  'rVuyi-dPMIc',
#  'm3fWCRvz5JA',
#  'kdiBc40gW7s',
#  'pCH4QrSx2Jg',
#  'cVaG6adE2mA',
#  'hHWOAUjnmjQ',
#  'jQfB4Gahi3I',
#  'dXNZaHuKWNA',
#  'eMcMbWl0fDk',
#  'TkAomsYFsJw',
#  'UNckfN9upqo',
#  'VN55tCajFYg',
#  'S4PuN-IWi2g',
#  'LmXn6BU16e0',
#  'PReSQYTFvcs',
#  '9boiT64sm0Q',
#  'AccGdO5XeZY',
#  'BZ-rLBkUZf4',
#  'D3mJe28un4M',
#  '3pj39qZZYoQ',
#  '4LtQxA_ooLk',
#  '9OQBDdNHmXo',
#  '-mrC5tRkxrY',
#  't0Yf43ONyNo',
#  'CUr_UwUUXzU',
#  'y8tF0yRl8-w',
#  'n0cde-Km05o',
#  'yuFuwXd-B9E',
#  'seU5y5EgIwk',
#  'qsUK-BG5OQQ',
#  'xSWVPqnKcXQ',
#  'jwWR1cQTKyw',
#  'vUHDR6Rg3Y4',
#  'cwFbq-70EwE',
#  'tMhiHrL7rPE',
#  'RcGowZ26sE0',
#  'rLCol1C3ouc',
#  'vwp8Ur6tO-8',
#  'dHdAN4FXzmc',
#  'ePjcjLRHPOo',
#  'T-41vMWQTUA',
#  'IsCik8wznlU',
#  'KZeI9I875Ig',
#  '7lLigiVgJsE',
#  'DlexmDDSDZ0',
#  '425n1NoRtgA',
#  'DNaSlUYIXBg',
#  '8bNlGwnEUAs',
#  '9-rKvhsjwKU',
#  'aOa6D6ku3dM',
#  'rFjJs6ZjPe8',
#  'XKaMUm7YwZc',
#  'FeTHyZJvozc',
#  'Uzii44SDYFA',
#  'aXzVF3XeS8M',
#  'Ur_wAcYDnuA',
#  '1iRbIYkccgw',
#  'iTNZ-OzBoBo',
#  'H9rBt-8jiBE',
#  'sViZJopFdYg',
#  'qybUgW7eoZQ',
#  '7XLW5CvDQ7E',
#  '3CUM7Z3TSmY',
#  'CYHt7_RANiY',
#  'qAGef4MdPdE',
#  'zI4DS5GmQWE',
#  'wMpqCRF7TKg',
#  'ukxEKY_7MOc',
#  'YPlNBb6I8qU',
#  'tP4TTgt4nb0',
#  'rqQHa2HcGtM',
#  'IEPomqor2A8',
#  'RsEZmictANA',
#  'hP6QpMeSG6s',
#  'c_p_TBaHvos',
#  '9nIOx-ezlzA',
#  'WuvhOD-mP8M',
#  'Pz-f9mM3Ms8',
#  'EXLgZZE072g',
#  '7EvwIw4gIyk',
#  'AIFnKqIeEdY',
#  'o5SQIECedTY',
#  'jgdFUoZzCI0',
#  'orXAg5dIMa8',
#  'tOHcAc3r2kw',
#  'GPQdWYNi8Wc',
#  'i50QUXDeC80',
#  'osdoLjUNFnA',
#  'ryLGxpjwAhM',
#  'pEY-GPsru_E',
#  'nn_0zPAfyo8',
#  'zLSUp53y-HQ',
#  'HpxX4ZE4KWE',
#  'K-a8s8OLBSE',
#  'OWbDJFtHl3w',
#  '9bdLTPNrlEg',
#  'KaM1bCuG4xo',
#  'MLV2SJKWk4M',
#  'OuFnpmGwg5k',
#  '6TAPqXkZW_I',
#  'KsZ6tROaVOQ',
#  '6DP4q_1EgQQ',
#  'DUnDkI7l9LQ',
#  '2s5xdY6MCeI',
#  'Vgt1d3eAm7A',
#  'rqsmrSyLTNM',
#  'JSD4XCBWzvs',
#  'd_2WyBcFbFY',
#  'DIMDgq_MYJs',
#  'Uxg-ivPGusQ',
#  '3xGvCApIEQY',
#  'a4iTHPwioEc',
#  'Tj6qU4dlKeA',
#  'kX6h4gDYLzM',
#  'o_CgCUINYmQ',
#  'IQL1vIP9sos',
#  'mxtUnuldKgc',
#  'a5gXfaAFPOM',
#  'AqAJLh9wuZ0',
#  'F3aXpa1rQEY',
#  'tbEekLA7J3Y',
#  'GJU-S1t2r1M',
#  '40RsbcFRwNA',
#  'O2Irnn7F1PM',
#  'hNHBVaFueYw',
#  'mN3rDTAdM2o',
#  'Ozk8xq0Lp1g',
#  'SVY8I46dkb0',
#  'KmT4Y8w1nho',
#  'RGJFqm1BnP4',
#  'trIjpVH8h88',
#  'b5Zay_Hd_7Q',
#  'kjD3LoXp-Pw',
#  'dmipFjOtMA8',
#  'hKcEdTPOGGw',
#  'pHoHDNxay3A',
#  'u9raS7-NisU',
#  'eaP1VswBF28',
#  'ic8j13piAhQ',
#  'p1cEvNn88jM',
#  'Kwf7P2GNAVw',
#  'tMoW5G5LU08',
#  'GTEFSuFfgnU',
#  'VikHHWrgb4Y',
#  'VsKoOH6DVys',
#  '8zdg-pDF10g',
#  '2d1wKn-oJnA',
#  'acQXa5ArHIk',
#  '8HxbqAsppwU',
#  'gRIWxlehJVg',
#  'iyYhqYELWtA',
#  'UY3UfH-ittk',
#  '1qwxqyac0Z8',
#  'dDO6HnY7h24',
#  '-BjZmE2gtdo',
#  'cvUAzpn48xA',
#  'PWdT2ONbJbc',
#  '8KpKc3C9V3w',
#  'SYd0pYqOJqA',
#  's4MN_hGvTCA',
#  '6MLzSp0OJL0',
#  'Dkk9gvTmCXY',
#  'GWtfOHBF1_w',
#  'MA0HQG9J9Yk',
#  '_zUCMfYkgj0',
#  'bqOfdv9i4sE',
#  'S--WI8PUVVo',
#  'lj2mZ8zDToY',
#  'MUf1ili4Zew',
#  'FuXNumBwDOM',
#  'HIb_TlK2HAI',
#  'RamgJyJsep4',
#  'MBR2kxt7RK8',
#  'aoYhTov8jsY',
#  'RMW3fAructY',
#  'zGSneb3McDo',
#  'sEr7bAtZ8rY',
#  'tCXGJQYZ9JA',
#  'VA7Y_Psp5l4',
#  'dfnCAmr569k',
#  'MvIwx0JThsk',
#  '66kn6Dcr12E',
#  'GZeza5xTeuM',
#  'oWVYzCPs3nE',
#  'eQVhAN7-IAw',
#  'kGOmPmILndU',
#  'V54CEElTF_U',
#  'wIft-t-MQuE',
#  'GU5_g8Tmiv8',
#  'EUoe7cf0HYw',
#  'np4Nw0tBun8',
#  '71QPEkD9PhM',
#  'e7HLU5-0VU4',
#  'jJeK0p1LanY',
#  'BKCmxyohzww',
#  'XF_ARz7jTUw',
#  'T62maKYX9tU',
#  '3tmd-ClpJxA',
#  'iM_j8_AZJW4',
#  '3K0RzZGpyds',
#  'J37Pitvp7RI',
#  'fJBFvNiJ4Kw',
#  'dwdtzwua2pY',
#  'QIUWI7dfnC0',
#  'OsJ5RyWpY5w',
#  '7F37r50VUTQ',
#  'wyK7YuwUWsU',
#  'TXJlB9riS1Y',
#  'p1Zt47V3pPw',
#  'OGDkg3QiJmk',
#  'JLf9q36UsBk',
#  'IdneKLhsWOQ',
#  'QcIy9NiNbmo',
#  'bKBJhghRfEk',
#  'cM2CXMcG5w8',
#  '-CmadmM5cOk',
#  'j3yyF31jbKo',
#  'BxZi6jC2JAI',
#  'e-ORhEE9VVg',
#  'JggOSZFlk0U',
#  '81doBkpkdJQ',
#  'xVKTOX3vMKM',
#  'EKnl7STzSMU',
#  'DqZOcABIgTk',
#  'M-M5SW8QvmY',
#  's8h0tZy0HqA',
#  'AoYtgGHfsG4',
#  'bs5SZOHowHI',
#  '70Ps-GzbSfw',
#  'vMWpIfxvnWo',
#  'TEpTNFHHjNg',
#  'kY-_D-IptZE',
#  'zdYy6-P_ggQ',
#  '1D5E5KLkfsI',
#  'nfWlot6h_JM',
#  'J1LMp-jEH_k',
#  'UfRqjF_8IqQ',
#  'kpzwfS5x068',
#  'QuijXg8wm28',
#  'DJXfSaOJXOQ',
#  'SvEbXNgvXWY',
#  'FTA4kzsTmxc',
#  '6wEVDvnqQOM',
#  'Ac7wMLgLtpY',
#  '41Zxe-tqjoE',
#  'y9yIBAmBDtk',
#  'EuT6nQvdcpo',
#  'C2giKOnk588',
#  'y7CsaOF3S5c',
#  'xmauy4h3rPg',
#  'Zlot0i3Zykw',
#  'YUSPwqd4674',
#  'LGA54hn8uwU',
#  'YfPfgZjhH1w',
#  'w1oM3kQpXRo',
#  '1hdDXzS63SY',
#  'JgkCFCOAn48',
#  'GDdVOpZkqRI',
#  'NZnRUnOQZWU',
#  '3H21433WdtU',
#  'Nx-5bHeC6xo',
#  'ueZmiOaDDlU',
#  'AgFeZr5ptV8',
#  'rghH6QlT5a0',
#  'jinbX0hwYOo',
#  'sIjKXPXjVxU',
#  'LyoTb3fxEnU',
#  '2obMo7y-rvA',
#  'vNoKguSdy4Y',
#  'OZJdxFEdjSU',
#  'BktS1hkMx_k',
#  'gQ0pP2z9niw',
#  'tvnGBYMe9gM',
#  'RQuY8kERaU0',
#  'cQ5tlnGg4wc',
#  'yfWgXcrNQIw',
#  'qbx_wdqaeV0',
#  'dgzN0Puq_hE',
#  '75NpXm04S1I',
#  'oo1CoPXIOuI',
#  'Rcex4Nw6Z9U',
#  '5FODVFJZlTg',
#  'Eo2D8Ez3WAo',
#  'FNWq-pr5ON8',
#  'XdalCja4TK8',
#  'YcuEHj-Nr58',
#  'ehLp0cjqkRk',
#  'sWgxCBXn2Y0',
#  'YoJj-5nAGpM',
#  'TGslPGte8Mw',
#  'TfjfzDIAIGE',
#  'YszERgNNKnc',
#  'yBHlFJ9waVo',
#  'k2zfi4gLekU',
#  'cMPEd8m79Hw',
#  'KNKa1to1v6o',
#  '1vj3YhYrULo',
#  'eocfbbyIUn8',
#  'WA4iX5D9Z64',
#  '6OPPGOl7ctE',
#  'gcMn_Eu-XTE',
#  'P6gFma4H7fA',
#  'I4TIvOCa3t8',
#  'weQBrpLffrA',
#  '8hsVICl7d8k',
#  'LkkY2iaylmI',
#  'tBEFMmkgu7s',
#  'FvodYNcH13Q',
#  'dLfkQNnzh2o',
#  'RzhAS_GnJIc',
#  'xDJLsPd6NdY',
#  'IdMI-HCO5QY',
#  'QvNW_z1Y7Ls',
#  'wIvJI6mF1ME',
#  'yHqjZUxaigo',
#  '7D6-_twz7YE',
#  '0Ot5C6O-KfA',
#  'HsLl-IL9c7E',
#  'gPJ8PFeq9Xw',
#  'Y89k5sfHBaw',
#  'h6CRgcouLuU',
#  '_zyYtE9di9A',
#  'AtHsg4USz8g',
#  'beGv3NTnduo',
#  'LZ34LlaIk88',
#  'O0Mnebw_TJc',
#  'lZNJnOrwDTQ',
#  'GSvyRVw366k',
#  'xIoApJgIw8U',
#  'woiScNulLyE',
#  '-CICulOcBQE',
#  'KFoOCZeKgzQ',
#  'urcHObkMCBE',
#  'OOPFMrF7v4Q',
#  'z___7lkxS0I',
#  'AcGbuveDwTg',
#  '_9RWI5JBew0',
#  'oKar-tF__ac',
#  'nN6VR92V70M',
#  'jYa1eI1hpDE',
#  've_o2kq4_jY',
#  'Zmv26eqduSg',
#  '9wXlz0f-2Zo',
#  'CpwF5fw6dE0',
#  'fTFcFeQOeLo',
#  'dlBQSxDuy2I',
#  'rx86WwyoI7g',
#  '-0uRcwk818Y',
#  'KWPrDngWZSQ',
#  '91EDAPQLsXc',
#  'LSjPFdoeDD8',
#  'jkin5pRLrQg',
#  'QUwxKWT6m7U',
#  'ZMt6TFO0zn4',
#  'zudLJdajX5Y',
#  '4wUPASp2hfY',
#  'xcLIGAIkztc',
#  'mNLVMDF9mUo',
#  'vio0RidOMUM',
#  '5jKcG86bNRs',
#  'QQVHNOxYv5E',
#  'XPBwXKgDTdE',
#  'w7p_BCIX-rw',
#  'IgZY0frgysw',
#  'uhHMWLjL77U',
#  'PVtlDvh74H8',
#  '37Pc4cjk9pY',
#  'Uo6HuSCBZu4',
#  'mxBSpHji2oo',
#  'U3yPyVFKGG8',
#  'VhFFAQuAUqo',
#  'ptSjNWnzpjg',
#  'Pb-K2tXWK4w',
#  'wzLhAZn_JMk',
#  'GVKuFZhB1e8',
#  'SnN7kIqDgz0',
#  'x2hRdQnbzKQ',
#  'Y3eRmLTN7FQ',
#  'Jb2stN7kH28',
#  'GkD20ajVxnY',
#  'xKCek6_dB0M',
#  'D1Xr-JFLxik',
#  'VuNIsY6JdUw',
#  '8xg3vE8Ie_E',
#  'l4_6eQm7RTQ',
#  'B1jYllE0T-k',
#  'AlTfYj7q5gQ',
#  'yCMqcFAigRg',
#  '8w4A1vVaNmE',
#  'V3QOzyS5M4Q',
#  'G2rSQF5Qx7k',
#  'MHDjff07l0I',
#  'M134RqAbiwY',
#  'qvcSth8LvEw',
#  '-zymq4JgQ7E',
#  '45KfDAgw_Is',
#  'RLmmqQNEM_I',
#  'rJVYkPjQf9s',
#  'DjABPXfE4Fs',
#  '0jWoq3COzts',
#  'bkADPxWSeak',
#  'm_4CSbzwPtE',
#  'Ivz6lNNAYaE',
#  'R7wjyOQw7Zw',
#  '1G1ES1y6AyI',
#  'Mi-FBBqUuJE',
#  'p-5R0u3iTiE',
#  'C7I3_yFQYkc',
#  'pA1dPsnfams',
#  'v9bxXO9fj98']

# %%
# -----------------------------
# Function: Get details for each video
# -----------------------------

# %%
# helper function to chunk a list into smaller lists of size n

def chunked(seq, n=50):
    it = iter(seq)
    while True:
        chunk = list(islice(it, n))
        if not chunk:
            break
        yield chunk

# %%
def get_category_mapping(youtube, region="US"):
    resp = youtube.videoCategories().list(part="snippet", regionCode=region).execute()
    return {item["id"]: item["snippet"]["title"] for item in resp.get("items", [])}

# %%
def parse_duration_seconds(iso_str):
    if not iso_str:
        return None
    try:
        return int(isodate.parse_duration(iso_str).total_seconds())
    except Exception:
        return None

# %%
def classify_video_type(snippet, content_details):
    live = snippet.get("liveBroadcastContent", "none")
    if live == "live":
        return "Live"
    if live == "upcoming":
        return "Upcoming Live"
    dur_s = parse_duration_seconds(content_details.get("duration"))
    if dur_s is not None and dur_s <= 60:
        return "Short"
    return "Regular"

# %%
def get_video_details(youtube, video_ids, region_for_categories="US"):
    """
    Returns a list of dicts with CategoryName, VideoType, and DurationSeconds.
    """
    category_map = get_category_mapping(youtube, region=region_for_categories)

    rows = []
    for chunk in chunked(video_ids, 50):
        resp = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=",".join(chunk)
        ).execute()

        for v in resp.get("items", []):
            snip = v.get("snippet", {})
            stats = v.get("statistics", {})
            cdet = v.get("contentDetails", {})

            cat_id = snip.get("categoryId")
            dur_s = parse_duration_seconds(cdet.get("duration"))

            rows.append({
                "VideoId": v.get("id"),
                "Title": snip.get("title"),
                "VideoType": classify_video_type(snip, cdet),
                "LiveStatus": snip.get("liveBroadcastContent", "none"),
                "CategoryId": cat_id,
                "CategoryName": category_map.get(cat_id, "Unknown"),
                "Published_date": snip.get("publishedAt"),
                "DurationSeconds": dur_s,
                "Views": stats.get("viewCount"),
                "Likes": stats.get("likeCount", 0),
                "Comments": stats.get("commentCount", 0),
            })
    return rows

# %%
# -----------------------------
# Frame data into DataFrame
# -----------------------------

# %%
video_details = get_video_details(youtube, video_ids, region_for_categories="US")
video_data = pd.DataFrame(video_details)

# %%
# -----------------------------
# Data cleaning & type conversion
# -----------------------------

# %%
video_data["Published_date"] = pd.to_datetime(video_data["Published_date"], errors="coerce")
for col in ["Views", "Likes", "Comments", "DurationSeconds"]:
    video_data[col] = pd.to_numeric(video_data[col], errors="coerce")

# %%
video_data = video_data[
    ["VideoId","Title","VideoType","LiveStatus","CategoryId","CategoryName",
     "Published_date","DurationSeconds","Views","Likes","Comments"]
]

video_data.head()
# Out:
#        VideoId                                              Title VideoType  \
# 0  9BTFD_gX6qQ  She’s got 4️⃣ days left to rehearse for her bi...     Short
# 1  zqaLqctWP28  The Life of a Showgirl: The Tiny Bubbles in Ch...     Short
# 2  BLFnkfAc7iY  The Life of a Showgirl: Baby, That’s Show Busi...     Short
# 3  0Xh9s_3uRO8  The Life of a Showgirl: The Shiny Bug Vinyl Co...     Short
# 4  w_DD-7_zVtw  And, baby, that’s show business for you. New a...     Short
#
#   LiveStatus CategoryId CategoryName            Published_date  \
# 0       none         10        Music 2025-09-29 13:14:31+00:00
# 1       none         10        Music 2025-08-25 20:02:56+00:00
# 2       none         10        Music 2025-08-21 18:04:53+00:00
# 3       none         10        Music 2025-08-18 18:13:43+00:00
# 4       none         10        Music 2025-08-14 05:00:58+00:00
#
#    DurationSeconds    Views   Likes  Comments
# 0               31   833643   80122      1589
# 1               16   580151   47982      2314
# 2               16   507088   42579      1173
# 3               16   615830   48458      1368
# 4                8  1588760  110471      3054

# %%
# -----------------------------
# Export full video dataset
# -----------------------------

# %%
video_data.to_csv('ts_video_data.csv', index=False, encoding='utf-8-sig')
